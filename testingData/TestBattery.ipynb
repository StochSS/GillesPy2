# %%
import sys
sys.path.append("/home/jackson/Research/GillesPy2/")
import gillespy2
from gillespy2.testing_battery import timing_battery

# %%
timing_battery(1000, "/home/jackson/StochKit/StochKit", .03)
# Out:
# Unable to use Cython optimized SSA:
# Error:No module named 'cython_ssa_solver'
# Testing Model : Trichloroethylene Solver : Basic SSA Solver.
# Testing Model : Trichloroethylene Solver : Basic Root Solver.
# Unacceptable deviation found on Model Trichloroethylene Solver Basic Root Solver with a deviation of 0.030000000000000027 on iteration 534. Exiting.
# name 'exit' is not defined
# Testing Model : Trichloroethylene Solver : Optimized SSA Solver.
# Unacceptable deviation found on Model Trichloroethylene Solver Optimized SSA Solver with a deviation of 0.98 on iteration 0. Exiting.
# name 'exit' is not defined
# Unacceptable deviation found on Model Trichloroethylene Solver Optimized SSA Solver with a deviation of 0.98 on iteration 1. Exiting.
# name 'exit' is not defined
# Unacceptable deviation found on Model Trichloroethylene Solver Optimized SSA Solver with a deviation of 0.98 on iteration 2. Exiting.
# name 'exit' is not defined
# ...
