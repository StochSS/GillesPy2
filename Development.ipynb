# %% [markdown]
# # BasicTauHybridSolver

# %% [markdown]
# ### Imports

# %%
import sys
import os
import numpy
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../../')))
import gillespy2.core.gillespySolver
import gillespy2
from gillespy2.core.gillespyError import SolverError, DirectoryError, BuildError, ExecutionError
from gillespy2.solvers.numpy.basic_tau_hybrid_solver import BasicTauHybridSolver

# %%
from gillespy2.core.results import Trajectory, Results
from gillespy2.core.gillespy2 import Model
trajectory = Trajectory(data={'time':[0.],'foo':[1.]}, model=Model('test_model'))
result = Results(data=[trajectory])

# %%
result.plot()

# %%
        import pickle
        trajectory_pickled=pickle.dumps(trajectory)

# %%
trajectory_unpickled = pickle.loads(trajectory_pickled)

# %%
print(trajectory_unpickled)
# Out:
# {'time': [0.0], 'foo': [1.0]}

# %%
results_pickled=pickle.dumps(result)
results_unpickled=pickle.loads(results_pickled)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-2ef916da43e6> in <module>
#       1 results_pickled=pickle.dumps(result)
# ----> 2 results_unpickled=pickle.loads(results_pickled)
#
# ~/Projects/GillesPy2/gillespy2/core/results.py in __getattribute__(self, key)
#     134         else:
#     135             if len(self.data)>1:
# --> 136                 warnings.warn("Results is of type list. Use results[i]['species'] instead of results['species'] ")
#     137             return(getattr(Results.__getattribute__(self,key='data')[0],key))
#     138
#
# ~/Projects/GillesPy2/gillespy2/core/results.py in __getattribute__(self, key)
#     132         if key == 'data':
#     133             return UserList.__getattribute__(self,'data')
# --> 134         else:
#     135             if len(self.data)>1:
# ...

# %%
print(result.data)
# Out:
# [{'time': [0.0], 'foo': [1.0]}]

# %%
print(result.__module__)
# Out:
# gillespy2.core.results

# %%
test_data = Trajectory({'time':[0]},model=Model('test_model'),solver_name='test_solver_name')
result = Results(data=[test_data])
print(result)
# Out:
# [{'time': [0]}]

# %%
import sys,os
result.to_csv(stamp='test_stamp',nametag='test_nametag')
# Out:
# 2020-05-16 10:49:42,602 - root - ERROR - Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/jdreeve/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-44-b61852f6b092>", line 2, in <module>
#     result.to_csv(stamp='test_stamp',nametag='test_nametag')
#   File "/home/jdreeve/Projects/GillesPy2/gillespy2/core/results.py", line 226, in to_csv
#     for i, trajectory in enumerate(self.data):#write each CSV file
# FileNotFoundError: [Errno 2] No such file or directory: './test_nametagtest_stamp'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jdreeve/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# ...
